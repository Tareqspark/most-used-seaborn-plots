# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
tips=sns.load_dataset("tips")
iris=sns.load_dataset("iris")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 0.1 1- Scatter Plot:
#
# A scatter plot is a two-dimensional plot that uses dots to represent the values for two different
# variables. It is useful for visualizing the relationship between two continuous variables. Seaborn’s
# scatterplot() function can be used to create scatter plots, with optional customization of colors,
# size, and shape of the markers.

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(data=tips,x="total_bill" , y="tip", hue= "time");
plt.title("Scatter plot");
plt.legend();

# %% [markdown]
# 0.2 2- Line Plot:
#
# A line plot is a graph that displays data points connected by straight lines. It is useful for showing
# trends over time or comparing changes in different groups. Seaborn’s lineplot() function can be
# used to create line plots, with optional customization of colors, markers, and line styles.

# %%
plt.figure(figsize=(4,3))
sns.lineplot(data=tips, x="day", y="total_bill" , hue="sex");
plt.title("Line plot");

# %% [markdown]
# 3- Histogram:
#
# A histogram is a graphical representation of the distribution of a dataset. It divides the range of
# values into a set of intervals, and then counts the number of values that fall into each interval.
# Seaborn’s histplot() function can be used to create histograms, with optional customization of bin
# size, color, and normalization.

# %%
plt.figure(figsize=(4, 3))
sns.histplot(data=tips, x='total_bill', bins=20)
plt.title('Histogram')
plt.show()

# %% [markdown]
#  4- Bar Plot:
#
# A bar plot is a graph that displays categorical data with rectangular bars. It is useful for comparing
# the values of different categories. Seaborn’s barplot() function can be used to create bar plots, with
# optional customization of colors, error bars, and confidence intervals.

# %%
plt.figure(figsize=(4, 3))
sns.barplot(data=tips, x='day', y='total_bill', hue='sex')
plt.title('Bar Plot')
#plt.legend()
plt.show()

# %% [markdown]
# 5- Box Plot:
#
# A box plot is a graph that displays the distribution of a dataset using five summary statistics:
# minimum, first quartile, median, third quartile, and maximum. It is useful for identifying outliers
# and comparing the distributions of different groups. Seaborn’s boxplot() function can be used to
# create box plots, with optional customization of colors, notch, and whisker length.

# %%
sns.boxplot(data=tips, x='day', y='total_bill', hue='sex')
plt.title('Box Plot');

# %% [markdown]
#  6- Heatmap:
#
# A heatmap is a graphical representation of a matrix of values, where the values are represented as
# colors. It is useful for visualizing patterns in large datasets. Seaborn’s heatmap() function can be
# used to create heatmaps, with optional customization of colors, annotation, and clustering.

# %%
plt.figure(figsize=(4, 3))
sns.heatmap(data=iris.corr(), annot=True)
plt.title('Heatmap');

# %% [markdown]
# 7- Pair Plot:
#
# A pair plot is a graph that displays pairwise relationships between variables in a dataset. It is
# useful for exploring the correlations between different variables. Seaborn’s pairplot() function can
# be used to create pair plots, with optional customization of diagonal plots, colors, and markers.

# %%
#plt.figure(figsize=(4, 3));
sns.pairplot(data=iris, hue='species', markers=['o', 's', 'D'])
plt.title('Pair Plot')
plt.show()

# %% [markdown]
# 8- Violin Plot:
#
# A violin plot is a combination of a box plot and a kernel density plot. It displays the distribution
# of a dataset with a combination of a box plot and a density plot, where the density plot shows the
# estimated probability density function. Seaborn’s violinplot() function can be used to create violin
# plots, with optional customization of colors, width, and inner quartile range.

# %%
plt.figure(figsize=(4, 3))
sns.violinplot(x="day", y="total_bill", data=tips)
plt.title('Violin Plot')
plt.show()

# %% [markdown]
#  9- Swarm Plot:
#
# A swarm plot is a graph that displays the distribution of a dataset by placing each data point
# on a line. It is useful for showing the density of data points and highlighting potential outliers.
# Seaborn’s swarmplot() function can be used to create swarm plots, with optional customization of
# colors and size.

# %%
plt.figure(figsize=(4, 3))
sns.swarmplot(data=tips, x='day', y='total_bill', hue='sex')
plt.title('Swarm Plot')
plt.show()

# %% [markdown]
# 10- Joint Plot:
#
# A joint plot is a graph that displays the relationship between two variables using both a scatter
# plot and a histogram. It is useful for exploring the correlations between different variables and
# identifying patterns in the data. Seaborn’s jointplot() function can be used to create joint plots,
# with optional customization of colors, markers, and regression lines.

# %%
#plt.figure(figsize=(4, 3))
sns.jointplot(data=tips, x='total_bill', y='tip', kind='reg')
plt.title('Joint Plot')
plt.show()
